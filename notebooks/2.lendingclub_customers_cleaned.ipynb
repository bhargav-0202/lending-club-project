# %%
from pyspark.sql import SparkSession
import getpass
username = getpass.getuser()
spark = SparkSession. \
    builder. \
    config('spark.ui.port','0'). \
    config('spark.shuffle.useOldFetchProtocol', 'true'). \
    config("spark.sql.warehouse.dir", f"/user/{username}/warehouse"). \
    enableHiveSupport(). \
    master('yarn'). \
    getOrCreate()

# %%
# !! hadoop fs -ls /public/trendytech/lendingclubproject/raw
# Out:
# ['Found 4 items',
#  'drwxr-xr-x   - itv005857 supergroup          0 2023-09-15 14:40 /public/trendytech/lendingclubproject/raw/customers_data_csv',
#  'drwxr-xr-x   - itv005857 supergroup          0 2023-09-17 22:57 /public/trendytech/lendingclubproject/raw/loans_data_csv',
#  'drwxr-xr-x   - itv005857 supergroup          0 2023-09-18 07:32 /public/trendytech/lendingclubproject/raw/loans_defaulters_csv',
#  'drwxr-xr-x   - itv005857 supergroup          0 2023-09-18 07:31 /public/trendytech/lendingclubproject/raw/loans_repayments_csv']

# %%
customers_raw_df = spark.read \
.format("csv") \
.option("header", True) \
.option("inferschema", True) \
.load("/public/trendytech/lendingclubproject/raw/customers_data_csv")

# %%
customers_raw_df
# Out:
# +--------------------+--------------------+----------+--------------+----------+----------+--------+-------+-----+---------+-------------------+---------------+----------------+----------------+-------------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_inc|addr_state|zip_code|country|grade|sub_grade|verification_status|tot_hi_cred_lim|application_type|annual_inc_joint|verification_status_joint|
# +--------------------+--------------------+----------+--------------+----------+----------+--------+-------+-----+---------+-------------------+---------------+----------------+----------------+-------------------------+
# |b59d80da191f5b573...|                null|      null|          RENT|   50000.0|        OR|   973xx|    USA|    A|       A5|    Source Verified|         8600.0|      Individual|            null|                     null|
# |202d9f56ecb7c3bc9...|      police officer|   7 years|           OWN|   85000.0|        TX|   799xx|    USA|    A|       A5|    Source Verified|       272384.0|      Individual|            null|                     null|
# |e5a140c0922b554b9...|community living ...|   6 years|          RENT|   48000.0|        NY|   146xx|    USA|    B|       B2|    Source Verified|        85092.0|      Individual|            null|                     null|
# |e12aefc548f750777...|              Office| 10+ years|           OWN|   33000.0|        CT|   067xx|    USA|    F|       F1|           Verified|         7100.0|      Individual|            null|                     null|
# |1b3a50d854fbbf97e...|Special Tooling I...| 10+ years|      MORTGAGE|   81000.0|        TX|   791xx|    USA|    E|       E5|           Verified|       190274.0|      Individual|            null|                     null|
# |1c4329e5f17697127...|     Mine ops tech 6|   2 years|      MORTGAGE|   68000.0|        AZ|   855xx|    USA|    C|       C3|       Not Verified|       182453.0|      Individual|            null|                     null|
# |5026c86ad983175eb...|           caregiver|   4 years|          RENT|   76020.0|        WA|   993xx|    USA|    C|       C2|    Source Verified|        15308.0|      Individual|            null|                     null|
# |9847d8c1e9d0b2084...|                null|      null|           OWN|   65000.0|        IL|   624xx|    USA|    E|       E3|           Verified|       128800.0|      Individual|            null|                     null|
# |8340dbe1adea41fb4...|Vice President Re...|   8 years|      MORTGAGE|  111000.0|        CT|   063xx|    USA|    A|       A1|       Not Verified|       343507.0|      Individual|            null|                     null|
# |d4de0de3ab7d79ad4...|             FOREMAN| 10+ years|      MORTGAGE|   67000.0|        WA|   992xx|    USA|    G|       G2|           Verified|       211501.0|      Individual|            null|                     null|
# |3df3cdeddb74a8712...|          Strategist|    1 year|          RENT|  120000.0|        CA|   946xx|    USA|    A|       A5|           Verified|        56844.0|      Individual|            null|                     null|
# |9dd72636b1b4045b4...|      Office Manager|   2 years|          RENT|   52000.0|        FL|   327xx|    USA|    D|       D1|    Source Verified|        39393.0|      Individual|            null|                     null|
# |1d4e1ef4353b73c00...|         Electrician|   2 years|      MORTGAGE|   50000.0|        IL|   606xx|    USA|    C|       C3|       Not Verified|        66064.0|      Individual|            null|                     null|
# |6f196952e71277fd4...|     Finance Manager|    1 year|      MORTGAGE|  125000.0|        GA|   310xx|    USA|    E|       E2|    Source Verified|       555591.0|      Individual|            null|                     null|
# |9c617cbc6e3e3d6a1...|  Nurse practitioner|   5 years|      MORTGAGE|  165000.0|        IL|   610xx|    USA|    F|       F1|    Source Verified|       366113.0|      Individual|            null|                     null|
# |45eb04dd75400a942...|  equipment operator|   3 years|      MORTGAGE|   60000.0|        CT|   064xx|    USA|    C|       C4|    Source Verified|       198693.0|      Individual|            null|                     null|
# |08d233c81f9e50726...|           caregiver|   2 years|          RENT|   36000.0|        MO|   648xx|    USA|    C|       C1|    Source Verified|        14477.0|      Individual|            null|                     null|
# |8ff4d0ed17a1cab92...|               owner| 10+ years|      MORTGAGE|   28000.0|        CO|   801xx|    USA|    D|       D1|           Verified|       314400.0|      Individual|            null|                     null|
# |aec13cfd611b2cfea...|Community Supervi...|   2 years|          RENT|   33000.0|        GA|   306xx|    USA|    D|       D2|    Source Verified|       188700.0|      Individual|            null|                     null|
# |9ba8c96ccba6cd1f0...| Contract Specialist|   5 years|      MORTGAGE|   74700.0|        UT|   844xx|    USA|    D|       D4|           Verified|       614272.0|      Individual|            null|                     null|
# +--------------------+--------------------+----------+--------------+----------+----------+--------+-------+-----+---------+-------------------+---------------+----------------+----------------+-------------------------+
# only showing top 20 rows

# %%
customers_raw_df.printSchema()
# Out:
# root
#  |-- member_id: string (nullable = true)
#  |-- emp_title: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: string (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- zip_code: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- sub_grade: string (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- tot_hi_cred_lim: double (nullable = true)
#  |-- application_type: string (nullable = true)
#  |-- annual_inc_joint: string (nullable = true)
#  |-- verification_status_joint: string (nullable = true)

# %% [markdown]
# ### 1. Create dataframe with proper datatypes

# %%
customers_schema = '''member_id string, emp_title string, emp_length string, home_ownership string, 
annual_inc float, addr_state string, zip_code string, country string, grade string, sub_grade string, 
verification_status string, tot_hi_cred_lim float, application_type string, annual_inc_joint float, verification_status_joint string'''

# %%
customers_raw_df = spark.read \
.format("csv") \
.option("header", True) \
.schema(customers_schema) \
.load("/public/trendytech/lendingclubproject/raw/customers_data_csv")

# %%
customers_raw_df.printSchema()
# Out:
# root
#  |-- member_id: string (nullable = true)
#  |-- emp_title: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: float (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- zip_code: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- sub_grade: string (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- tot_hi_cred_lim: float (nullable = true)
#  |-- application_type: string (nullable = true)
#  |-- annual_inc_joint: float (nullable = true)
#  |-- verification_status_joint: string (nullable = true)

# %% [markdown]
# ### 2. Rename few columns
#
# #### withColumnRenamed("annual_inc","annual_income")
# #### withColumnRenamed("addr_state","address_state")
# #### withColumnRenamed("zip_code","address_zipcode")
# #### withColumnRenamed("country","address_country")
# #### withColumnRenamed("tot_hi_cred_lim","total_high_credit_limit")
# #### withColumnRenamed("annual_inc_joint","join_annual_income")

# %%
customers_df_renamed = customers_raw_df.withColumnRenamed("annual_inc","annual_income") \
.withColumnRenamed("addr_state","address_state") \
.withColumnRenamed("zip_code","address_zipcode")\
.withColumnRenamed("country","address_country") \
.withColumnRenamed("tot_hi_cred_lim","total_high_credit_limit") \
.withColumnRenamed("annual_inc_joint","join_annual_income")

# %%
customers_df_renamed
# Out:
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_income|address_state|address_zipcode|address_country|grade|sub_grade|verification_status|total_high_credit_limit|application_type|join_annual_income|verification_status_joint|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+
# |b59d80da191f5b573...|                null|      null|          RENT|      50000.0|           OR|          973xx|            USA|    A|       A5|    Source Verified|                 8600.0|      Individual|              null|                     null|
# |202d9f56ecb7c3bc9...|      police officer|   7 years|           OWN|      85000.0|           TX|          799xx|            USA|    A|       A5|    Source Verified|               272384.0|      Individual|              null|                     null|
# |e5a140c0922b554b9...|community living ...|   6 years|          RENT|      48000.0|           NY|          146xx|            USA|    B|       B2|    Source Verified|                85092.0|      Individual|              null|                     null|
# |e12aefc548f750777...|              Office| 10+ years|           OWN|      33000.0|           CT|          067xx|            USA|    F|       F1|           Verified|                 7100.0|      Individual|              null|                     null|
# |1b3a50d854fbbf97e...|Special Tooling I...| 10+ years|      MORTGAGE|      81000.0|           TX|          791xx|            USA|    E|       E5|           Verified|               190274.0|      Individual|              null|                     null|
# |1c4329e5f17697127...|     Mine ops tech 6|   2 years|      MORTGAGE|      68000.0|           AZ|          855xx|            USA|    C|       C3|       Not Verified|               182453.0|      Individual|              null|                     null|
# |5026c86ad983175eb...|           caregiver|   4 years|          RENT|      76020.0|           WA|          993xx|            USA|    C|       C2|    Source Verified|                15308.0|      Individual|              null|                     null|
# |9847d8c1e9d0b2084...|                null|      null|           OWN|      65000.0|           IL|          624xx|            USA|    E|       E3|           Verified|               128800.0|      Individual|              null|                     null|
# |8340dbe1adea41fb4...|Vice President Re...|   8 years|      MORTGAGE|     111000.0|           CT|          063xx|            USA|    A|       A1|       Not Verified|               343507.0|      Individual|              null|                     null|
# |d4de0de3ab7d79ad4...|             FOREMAN| 10+ years|      MORTGAGE|      67000.0|           WA|          992xx|            USA|    G|       G2|           Verified|               211501.0|      Individual|              null|                     null|
# |3df3cdeddb74a8712...|          Strategist|    1 year|          RENT|     120000.0|           CA|          946xx|            USA|    A|       A5|           Verified|                56844.0|      Individual|              null|                     null|
# |9dd72636b1b4045b4...|      Office Manager|   2 years|          RENT|      52000.0|           FL|          327xx|            USA|    D|       D1|    Source Verified|                39393.0|      Individual|              null|                     null|
# |1d4e1ef4353b73c00...|         Electrician|   2 years|      MORTGAGE|      50000.0|           IL|          606xx|            USA|    C|       C3|       Not Verified|                66064.0|      Individual|              null|                     null|
# |6f196952e71277fd4...|     Finance Manager|    1 year|      MORTGAGE|     125000.0|           GA|          310xx|            USA|    E|       E2|    Source Verified|               555591.0|      Individual|              null|                     null|
# |9c617cbc6e3e3d6a1...|  Nurse practitioner|   5 years|      MORTGAGE|     165000.0|           IL|          610xx|            USA|    F|       F1|    Source Verified|               366113.0|      Individual|              null|                     null|
# |45eb04dd75400a942...|  equipment operator|   3 years|      MORTGAGE|      60000.0|           CT|          064xx|            USA|    C|       C4|    Source Verified|               198693.0|      Individual|              null|                     null|
# |08d233c81f9e50726...|           caregiver|   2 years|          RENT|      36000.0|           MO|          648xx|            USA|    C|       C1|    Source Verified|                14477.0|      Individual|              null|                     null|
# |8ff4d0ed17a1cab92...|               owner| 10+ years|      MORTGAGE|      28000.0|           CO|          801xx|            USA|    D|       D1|           Verified|               314400.0|      Individual|              null|                     null|
# |aec13cfd611b2cfea...|Community Supervi...|   2 years|          RENT|      33000.0|           GA|          306xx|            USA|    D|       D2|    Source Verified|               188700.0|      Individual|              null|                     null|
# |9ba8c96ccba6cd1f0...| Contract Specialist|   5 years|      MORTGAGE|      74700.0|           UT|          844xx|            USA|    D|       D4|           Verified|               614272.0|      Individual|              null|                     null|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+
# only showing top 20 rows

# %% [markdown]
# ### 3. Insert a new column named as ingestion date(current time)

# %%
from pyspark.sql.functions import current_timestamp

# %%
customers_df_ingested = customers_df_renamed.withColumn("ingest_date", current_timestamp())

# %%
customers_df_ingested
# Out:
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_income|address_state|address_zipcode|address_country|grade|sub_grade|verification_status|total_high_credit_limit|application_type|join_annual_income|verification_status_joint|         ingest_date|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |b59d80da191f5b573...|                null|      null|          RENT|      50000.0|           OR|          973xx|            USA|    A|       A5|    Source Verified|                 8600.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |202d9f56ecb7c3bc9...|      police officer|   7 years|           OWN|      85000.0|           TX|          799xx|            USA|    A|       A5|    Source Verified|               272384.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |e5a140c0922b554b9...|community living ...|   6 years|          RENT|      48000.0|           NY|          146xx|            USA|    B|       B2|    Source Verified|                85092.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |e12aefc548f750777...|              Office| 10+ years|           OWN|      33000.0|           CT|          067xx|            USA|    F|       F1|           Verified|                 7100.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |1b3a50d854fbbf97e...|Special Tooling I...| 10+ years|      MORTGAGE|      81000.0|           TX|          791xx|            USA|    E|       E5|           Verified|               190274.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |1c4329e5f17697127...|     Mine ops tech 6|   2 years|      MORTGAGE|      68000.0|           AZ|          855xx|            USA|    C|       C3|       Not Verified|               182453.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |5026c86ad983175eb...|           caregiver|   4 years|          RENT|      76020.0|           WA|          993xx|            USA|    C|       C2|    Source Verified|                15308.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |9847d8c1e9d0b2084...|                null|      null|           OWN|      65000.0|           IL|          624xx|            USA|    E|       E3|           Verified|               128800.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |8340dbe1adea41fb4...|Vice President Re...|   8 years|      MORTGAGE|     111000.0|           CT|          063xx|            USA|    A|       A1|       Not Verified|               343507.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |d4de0de3ab7d79ad4...|             FOREMAN| 10+ years|      MORTGAGE|      67000.0|           WA|          992xx|            USA|    G|       G2|           Verified|               211501.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |3df3cdeddb74a8712...|          Strategist|    1 year|          RENT|     120000.0|           CA|          946xx|            USA|    A|       A5|           Verified|                56844.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |9dd72636b1b4045b4...|      Office Manager|   2 years|          RENT|      52000.0|           FL|          327xx|            USA|    D|       D1|    Source Verified|                39393.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |1d4e1ef4353b73c00...|         Electrician|   2 years|      MORTGAGE|      50000.0|           IL|          606xx|            USA|    C|       C3|       Not Verified|                66064.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |6f196952e71277fd4...|     Finance Manager|    1 year|      MORTGAGE|     125000.0|           GA|          310xx|            USA|    E|       E2|    Source Verified|               555591.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |9c617cbc6e3e3d6a1...|  Nurse practitioner|   5 years|      MORTGAGE|     165000.0|           IL|          610xx|            USA|    F|       F1|    Source Verified|               366113.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |45eb04dd75400a942...|  equipment operator|   3 years|      MORTGAGE|      60000.0|           CT|          064xx|            USA|    C|       C4|    Source Verified|               198693.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |08d233c81f9e50726...|           caregiver|   2 years|          RENT|      36000.0|           MO|          648xx|            USA|    C|       C1|    Source Verified|                14477.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |8ff4d0ed17a1cab92...|               owner| 10+ years|      MORTGAGE|      28000.0|           CO|          801xx|            USA|    D|       D1|           Verified|               314400.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |aec13cfd611b2cfea...|Community Supervi...|   2 years|          RENT|      33000.0|           GA|          306xx|            USA|    D|       D2|    Source Verified|               188700.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# |9ba8c96ccba6cd1f0...| Contract Specialist|   5 years|      MORTGAGE|      74700.0|           UT|          844xx|            USA|    D|       D4|           Verified|               614272.0|      Individual|              null|                     null|2026-01-17 23:21:...|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### 4.Remove all the duplicate rows

# %%
customers_df_ingested.count()
# Out:
# 2260701

# %%
customers_distinct = customers_df_ingested.distinct()

# %%
customers_distinct.count()
# Out:
# 2260638

# %% [markdown]
# ## this customers_distinct will not have any dupicate rows init lets create a table out of it (as its having unique rows)

# %%
customers_distinct.createOrReplaceTempView("customers")

# %%
spark.sql("select count(*) from customers")
# Out:
# +--------+
# |count(1)|
# +--------+
# | 2260638|
# +--------+

# %%
spark.sql("select * from customers")
# Out:
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_income|address_state|address_zipcode|address_country|grade|sub_grade|verification_status|total_high_credit_limit|application_type|join_annual_income|verification_status_joint|         ingest_date|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |799f3f6e927858c02...|               owner|   5 years|      MORTGAGE|      50000.0|           NJ|          070xx|            USA|    B|       B4|    Source Verified|                72481.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |71a0c21b64a38a383...|   Marketing Manager|   5 years|          RENT|      65000.0|           IL|          627xx|            USA|    A|       A4|       Not Verified|                62431.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |c20cb6f824ce6ca63...|International Shi...|   4 years|      MORTGAGE|      59500.0|           CA|          906xx|            USA|    A|       A4|    Source Verified|                81400.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |995c44571fe6dddfc...|Residential progr...|   9 years|          RENT|      50000.0|           NJ|          074xx|            USA|    C|       C4|       Not Verified|                64354.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |d110fa95d349a2e40...|                null|      null|      MORTGAGE|      70000.0|           NY|          119xx|            USA|    D|       D1|           Verified|               318075.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |b42865c47fdf72afd...|                null|      null|           OWN|      25000.0|           VA|          229xx|            USA|    F|       F4|           Verified|                32000.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |0ed49029356d18d8b...|Force Development...| 10+ years|      MORTGAGE|     110000.0|           NM|          883xx|            USA|    C|       C3|    Source Verified|               304521.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |26c1985bf98b05bb0...|    District Manager|   5 years|      MORTGAGE|      69000.0|           FL|          328xx|            USA|    D|       D2|           Verified|                29541.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |df67f3426fc22e039...|Corporate Ergonomist|   6 years|      MORTGAGE|     103000.0|           NC|          287xx|            USA|    B|       B4|    Source Verified|               153679.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |6769e5950c408cbe3...|    CLIENT RELATIONS|   4 years|      MORTGAGE|      84000.0|           CA|          900xx|            USA|    B|       B3|    Source Verified|               392120.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |5bd30873f128fd23e...|            DIRECTOR|   4 years|      MORTGAGE|     110000.0|           WA|          980xx|            USA|    C|       C5|           Verified|               655504.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |0c6d96053f4325cf8...|               Owner| 10+ years|      MORTGAGE|     120000.0|           KY|          425xx|            USA|    A|       A3|           Verified|               380810.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |53884509c91f73fd7...|                null|      null|          RENT|      24000.0|           WA|          983xx|            USA|    A|       A1|       Not Verified|                36300.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |a819be1755ce873f7...|  Associate Attorney|   7 years|      MORTGAGE|     200000.0|           MA|          021xx|            USA|    A|       A2|    Source Verified|               321890.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |e6faf3294fe0b6e2a...|                  RN| 10+ years|      MORTGAGE|      65000.0|           TX|          799xx|            USA|    B|       B3|    Source Verified|               262995.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |ad48373077c494ba7...|             Freight|   8 years|           OWN|      38800.0|           TX|          781xx|            USA|    D|       D2|           Verified|               119100.0|       Joint App|           77600.0|          Source Verified|2026-01-17 23:22:...|
# |fc6d834e3bf3da1c9...|    Registered nurse| 10+ years|           OWN|     102000.0|           NY|          104xx|            USA|    C|       C2|           Verified|               313010.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |a01ce421a8b378b08...|       Sales Manager| 10+ years|           OWN|     155000.0|           VA|          244xx|            USA|    D|       D1|    Source Verified|               232113.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |748f1ef3b9eb5076f...|    machine operator|   2 years|           OWN|      40000.0|           FL|          334xx|            USA|    E|       E3|    Source Verified|                73700.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |1979b7dbf7cd8545c...|               Owner|   4 years|      MORTGAGE|      85000.0|           NY|          117xx|            USA|    C|       C4|       Not Verified|                52032.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## 5. Remove the rows where annual_income is null

# %%
spark.sql("select count(*) from customers where annual_income is null")
# Out:
# +--------+
# |count(1)|
# +--------+
# |       5|
# +--------+

# %%
spark.sql("select count(*) from customers where annual_income is not null")
# Out:
# +--------+
# |count(1)|
# +--------+
# | 2260633|
# +--------+

# %%
customers_income_filtered = spark.sql("select * from customers where annual_income is not null")

# %%
customers_income_filtered.createOrReplaceTempView("customers")

# so inthis customers table we removed all the null values

# %% [markdown]
# ## 6. Convert emp_length into integer

# %%
spark.sql("select distinct(emp_length) from customers").show()
# Out:
# +----------+
# |emp_length|
# +----------+
# |   5 years|
# |   9 years|
# |      null|
# |    1 year|
# |   2 years|
# |   7 years|
# |   8 years|
# |   4 years|
# |   6 years|
# |   3 years|
# | 10+ years|
# |  < 1 year|
# +----------+

# %%
from pyspark.sql.functions import regexp_replace, col

# %%
customers_emplength_cleaned = customers_income_filtered.withColumn("emp_length",regexp_replace(col("emp_length"),"(\D)",""))


## here withColumn- Creates if not exist or Replaces the column if exist 
# we are applyting withColumn for emp_length and using a regular expression
# we are using regexp_replace on column named emp_length for those values whos is having non digit "(/D)" replace it with empty ""

# %%
customers_emplength_cleaned
# Out:
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_income|address_state|address_zipcode|address_country|grade|sub_grade|verification_status|total_high_credit_limit|application_type|join_annual_income|verification_status_joint|         ingest_date|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |707938a470aafbeba...|        Brass caster|        10|          RENT|      70000.0|           NY|          141xx|            USA|    C|       C5|           Verified|                64925.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |c19317cc688e1d4dc...|Progrma support A...|        10|           OWN|      52000.0|           IN|          462xx|            USA|    C|       C5|    Source Verified|                45712.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |5b26744dc0d314db6...|        truck driver|         1|          RENT|      85000.0|           ND|          588xx|            USA|    D|       D2|       Not Verified|                99665.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |919766e3dcf219941...| physician assistant|         4|          RENT|     115000.0|           NY|          104xx|            USA|    B|       B3|    Source Verified|                37200.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |7247d89bdefd8a58f...|                null|      null|          RENT|      12000.0|           OK|          731xx|            USA|    C|       C3|           Verified|                24032.0|       Joint App|           62000.0|                 Verified|2026-01-17 23:22:...|
# |8aa0512a1a25863b5...|        Food service|         8|      MORTGAGE|      12000.0|           IN|          461xx|            USA|    D|       D2|       Not Verified|               179351.0|       Joint App|          132000.0|             Not Verified|2026-01-17 23:22:...|
# |2e29393740617fae8...|                null|      null|      MORTGAGE|     42959.16|           GA|          306xx|            USA|    A|       A2|       Not Verified|               128000.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |0425c248bb541f88a...|             Account|         4|      MORTGAGE|      55000.0|           CA|          906xx|            USA|    D|       D1|    Source Verified|               425137.0|       Joint App|          115000.0|          Source Verified|2026-01-17 23:22:...|
# |0e37c71081c0d43f7...|    Business Manager|         7|      MORTGAGE|     102000.0|           WA|          986xx|            USA|    C|       C3|           Verified|               442993.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |89971c173520aac58...|    Dean of Students|         4|      MORTGAGE|     162000.0|           IL|          604xx|            USA|    C|       C3|           Verified|               494759.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |ef878eb36a1aefcfb...|National Account ...|         1|      MORTGAGE|     240000.0|           AL|          352xx|            USA|    B|       B4|    Source Verified|               814699.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |ece1dca1babb181ae...|Admin Office Coor...|        10|          RENT|      80000.0|           MI|          483xx|            USA|    D|       D2|    Source Verified|                53390.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |e03eb24414ce6dd6e...|            HR admin|         5|      MORTGAGE|      60000.0|           IL|          604xx|            USA|    E|       E4|    Source Verified|               121013.0|       Joint App|          216000.0|          Source Verified|2026-01-17 23:22:...|
# |ccb55a7a98d049614...|             Realtor|         3|          RENT|      55000.0|           CA|          900xx|            USA|    C|       C4|    Source Verified|                 5100.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |adbe50ef31bd595b6...|     LABORER FOREMAN|        10|      MORTGAGE|      80000.0|           MO|          633xx|            USA|    B|       B4|           Verified|               244857.0|       Joint App|          102000.0|                 Verified|2026-01-17 23:22:...|
# |b502a68b8842825a7...| Gas Control Analyst|        10|      MORTGAGE|     120000.0|           CT|          066xx|            USA|    B|       B5|       Not Verified|               414856.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |4e05c0d8b1f6598e3...|                null|      null|      MORTGAGE|      22320.0|           CO|          816xx|            USA|    B|       B5|           Verified|               324616.0|       Joint App|           42320.0|                 Verified|2026-01-17 23:22:...|
# |587ffb3bc65934364...|  Operations Manager|         2|          RENT|     147000.0|           NY|          112xx|            USA|    D|       D2|           Verified|                39900.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |6a90f28b56d678bd9...|                 12B|         7|      MORTGAGE|      69000.0|           TX|          765xx|            USA|    B|       B2|           Verified|               233860.0|       Joint App|          121800.0|          Source Verified|2026-01-17 23:22:...|
# |e6d96473bbf97c4c5...|                  AP|         3|          RENT|      50000.0|           MN|          551xx|            USA|    D|       D1|           Verified|                59118.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# only showing top 20 rows

# %%
customers_emplength_cleaned.printSchema()
# Out:
# root
#  |-- member_id: string (nullable = true)
#  |-- emp_title: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_income: float (nullable = true)
#  |-- address_state: string (nullable = true)
#  |-- address_zipcode: string (nullable = true)
#  |-- address_country: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- sub_grade: string (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- total_high_credit_limit: float (nullable = true)
#  |-- application_type: string (nullable = true)
#  |-- join_annual_income: float (nullable = true)
#  |-- verification_status_joint: string (nullable = true)
#  |-- ingest_date: timestamp (nullable = false)

# %%
customers_emplength_casted = customers_emplength_cleaned.withColumn("emp_length",customers_emplength_cleaned.emp_length.cast('int'))

# %%
customers_emplength_casted
# Out:
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_income|address_state|address_zipcode|address_country|grade|sub_grade|verification_status|total_high_credit_limit|application_type|join_annual_income|verification_status_joint|         ingest_date|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |52c85c5e973bf1bb0...|Director of clien...|         2|          RENT|     155000.0|           IL|          601xx|            USA|    A|       A2|       Not Verified|               148469.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |9dd07ce00d876f755...|Admissions Repres...|         1|          RENT|      35000.0|           NC|          282xx|            USA|    B|       B2|           Verified|               144370.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |28eb33bfeb70b6d36...|            Director|         1|      MORTGAGE|     120000.0|           CA|          931xx|            USA|    C|       C2|           Verified|               540610.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |3bded74c1c1d295a0...|Business Operatio...|         1|           OWN|      40000.0|           CA|          940xx|            USA|    D|       D1|    Source Verified|                55082.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |bf42f37bb01c9d757...|State Fire Marsha...|        10|      MORTGAGE|      69000.0|           VA|          240xx|            USA|    A|       A2|    Source Verified|               172912.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |7738fa38adf9a911c...| Sr. Account Manager|         1|          RENT|     325000.0|           NJ|          077xx|            USA|    A|       A1|    Source Verified|               404468.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |879205346ef5ace0f...| Sr. Account Manager|         1|      MORTGAGE|     200000.0|           MA|          018xx|            USA|    A|       A5|    Source Verified|               396456.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |66e0b1e3ea8334f0b...|                null|      null|      MORTGAGE|      22620.0|           TN|          371xx|            USA|    B|       B1|       Not Verified|                96464.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |6a849d8facfeea4ec...|Commercial Lender...|         3|          RENT|     128000.0|           NJ|          080xx|            USA|    A|       A5|           Verified|               407637.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |93a0ddad4b092b1c3...|            Bus Aide|        10|          RENT|      28500.0|           MI|          490xx|            USA|    D|       D2|    Source Verified|                33472.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |68881afa94087876c...|             Teacher|        10|      MORTGAGE|      51500.0|           WI|          549xx|            USA|    A|       A1|       Not Verified|               243348.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |782dd08767d314a57...|  marketing director|        10|      MORTGAGE|     109000.0|           NC|          281xx|            USA|    C|       C1|       Not Verified|               270848.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |8e755e4c2a9ff2502...|        Mail carrier|        10|           OWN|      63000.0|           NY|          120xx|            USA|    D|       D1|       Not Verified|                25713.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |0f070465ead570213...|Senior Youth Care...|        10|      MORTGAGE|      50000.0|           TN|          372xx|            USA|    A|       A1|    Source Verified|               208683.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |55ea9d2c7e12c2bc3...|                  RN|         6|      MORTGAGE|      73000.0|           OH|          436xx|            USA|    C|       C3|    Source Verified|                99597.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |8b8cb5817589157f5...|  Associate Director|         6|      MORTGAGE|     125000.0|           OH|          441xx|            USA|    C|       C5|    Source Verified|               154326.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |04c7cd22fecf79527...|               owner|        10|          RENT|     150000.0|           NJ|          079xx|            USA|    C|       C2|       Not Verified|               179419.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |adcc50bfb07bf31fd...|                null|      null|      MORTGAGE|     124500.0|           GA|          318xx|            USA|    E|       E1|    Source Verified|               649424.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |b30d439a367481006...|                 DSR|         2|           OWN|      60000.0|           IN|          468xx|            USA|    C|       C4|       Not Verified|               155314.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# |6aa26f1da6f5722f8...|Supervisor Custom...|        10|          RENT|      65000.0|           TX|          750xx|            USA|    E|       E1|           Verified|                90379.0|      Individual|              null|                     null|2026-01-17 23:22:...|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# only showing top 20 rows

# %%
customers_emplength_casted.printSchema()
# Out:
# root
#  |-- member_id: string (nullable = true)
#  |-- emp_title: string (nullable = true)
#  |-- emp_length: integer (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_income: float (nullable = true)
#  |-- address_state: string (nullable = true)
#  |-- address_zipcode: string (nullable = true)
#  |-- address_country: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- sub_grade: string (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- total_high_credit_limit: float (nullable = true)
#  |-- application_type: string (nullable = true)
#  |-- join_annual_income: float (nullable = true)
#  |-- verification_status_joint: string (nullable = true)
#  |-- ingest_date: timestamp (nullable = false)

# %% [markdown]
# ## 7. Replace all the nulls in emp_length column with average of this column

# %%
customers_emplength_casted.filter("emp_length is null").count()
# Out:
# 146903

# %%
customers_emplength_casted.createOrReplaceTempView("customers")

# %%
avg_emp_length = spark.sql("""select floor(avg(emp_length)) as avg_emp_length from customers""").collect()

# %%
print(avg_emp_length)
# Out:
# [Row(avg_emp_length=6)]

# %%
avg_emp_duration = avg_emp_length[0][0]

# %%
avg_emp_duration
# Out:
# 6

# %%
customers_emplength_replaced = customers_emplength_casted.na.fill(avg_emp_duration,subset = ['emp_length'])

# %%
customers_emplength_replaced.filter("emp_length is null").count()
# Out:
# 0

# %%
customers_emplength_replaced
# Out:
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_income|address_state|address_zipcode|address_country|grade|sub_grade|verification_status|total_high_credit_limit|application_type|join_annual_income|verification_status_joint|         ingest_date|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |1ae20f15b198b8cee...|   Hardware Engineer|         1|      MORTGAGE|     142438.0|           CA|          926xx|            USA|    A|       A1|       Not Verified|               532726.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |20b81bc7acff578c4...|     Senior Attorney|         6|          RENT|     140000.0|           CA|          902xx|            USA|    A|       A2|       Not Verified|               209383.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |30222329712e9aad9...|Certified Medical...|         4|      MORTGAGE|      45000.0|           IL|          604xx|            USA|    C|       C2|       Not Verified|               172757.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |a53663f382fad9613...|    Sales Specialist|         2|          RENT|      78000.0|           NY|          104xx|            USA|    B|       B3|           Verified|                36603.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |bb14dbf40d9ed61e8...|           Draftsman|         1|          RENT|      25000.0|           LA|          703xx|            USA|    D|       D3|    Source Verified|                43580.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |7edc527111d4d3125...|              driver|        10|           OWN|      90000.0|           PA|          191xx|            USA|    D|       D1|       Not Verified|                76721.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |ed07ab554e019f3d9...|Technical Supervisor|         4|          RENT|      56000.0|           NY|          104xx|            USA|    F|       F3|           Verified|                12968.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |ec84952ae3d95241e...|               Sales|         2|      MORTGAGE|      35559.0|           CO|          802xx|            USA|    B|       B2|       Not Verified|               244404.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |e668f8ca0f78efe85...|Front Office Navi...|         1|          RENT|      27302.0|           OR|          971xx|            USA|    D|       D4|    Source Verified|                48327.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |db0e308400c7e61c8...|Consumer Safety I...|        10|           OWN|      84000.0|           FL|          329xx|            USA|    D|       D1|    Source Verified|                24412.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |8de37efa5bef9e1fb...|Antenna Design En...|         2|      MORTGAGE|     107000.0|           CT|          064xx|            USA|    A|       A1|       Not Verified|               395932.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |1af9627731ed23519...|Construction Manager|         1|      MORTGAGE|      52000.0|           TX|          750xx|            USA|    C|       C5|    Source Verified|                32172.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |aa507e38b486ce678...|    registered nurse|         6|          RENT|      85000.0|           NJ|          073xx|            USA|    C|       C2|    Source Verified|                77001.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |5faf2b46de3fe988c...|Director of Corpo...|         5|          RENT|     150000.0|           VA|          201xx|            USA|    D|       D4|    Source Verified|                54139.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |41b2d4aecc8bfb0bb...|        Radiographer|        10|      MORTGAGE|     120000.0|           AK|          996xx|            USA|    C|       C1|    Source Verified|               291548.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |0bac575e2859536f6...|  Operations Analyst|         1|           OWN|      61000.0|           NY|          119xx|            USA|    C|       C1|    Source Verified|                91773.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |d7f21e152bffc7ea7...|  Transit Bus Driver|         4|      MORTGAGE|      83400.0|           PA|          156xx|            USA|    B|       B3|       Not Verified|               237723.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |dfde5421aa8131c80...|             Teacher|         1|          RENT|      46000.0|           CA|          905xx|            USA|    B|       B5|    Source Verified|                58775.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |3597b297e4a1969cc...|                  RN|         9|           OWN|      85000.0|           NJ|          080xx|            USA|    C|       C3|           Verified|               388390.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |d1b0b482768021667...|Financial Product...|         8|      MORTGAGE|      54590.0|           CA|          928xx|            USA|    D|       D4|    Source Verified|               105752.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Clean address state (it should be two characters only) replace alll other with NA

# %%
customers_emplength_replaced.createOrReplaceTempView("customers")

# %%
spark.sql("select distinct(address_state) from customers")
# Out:
# +--------------------+
# |       address_state|
# +--------------------+
# |Helping Kenya's D...|
# |               223xx|
# |175 (total projec...|
# |                  AZ|
# |                  SC|
# |so Plan ""C"" is ...|
# |I am 56 yrs. old ...|
# |financially I mad...|
# |but no one will l...|
# |                  LA|
# |         etc.  First|
# |                  MN|
# |yet Capital One n...|
# |               850xx|
# |               499xx|
# |Eliminating Credi...|
# |and MBA's are ove...|
# |Advocate business...|
# |I the credit card...|
# |               951xx|
# +--------------------+
# only showing top 20 rows

# %%
spark.sql("select count(address_state) from customers where length(address_state)>2")
# Out:
# +--------------------+
# |count(address_state)|
# +--------------------+
# |                 254|
# +--------------------+

# %%
from pyspark.sql.functions import when, col, length

# %%
customers_state_cleaned = customers_emplength_replaced.withColumn(
    "address_state",
    when(length(col("address_state"))>2,"NA").otherwise(col("address_state"))
    )

# %%
customers_state_cleaned
# Out:
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |           member_id|           emp_title|emp_length|home_ownership|annual_income|address_state|address_zipcode|address_country|grade|sub_grade|verification_status|total_high_credit_limit|application_type|join_annual_income|verification_status_joint|         ingest_date|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# |d97586f5f0099a0f6...| Closing Coordinator|         1|          RENT|      40000.0|           PA|          152xx|            USA|    D|       D5|       Not Verified|               118533.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |bd012e2c0af87c7f7...|             Teacher|         3|          RENT|      55000.0|           NJ|          079xx|            USA|    C|       C1|       Not Verified|               175594.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |ceef8523545f09930...|  Executive Director|         5|          RENT|     125000.0|           NY|          112xx|            USA|    B|       B2|           Verified|               161695.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |097b7da179b3e2959...|    business manager|         5|          RENT|      60000.0|           NY|          104xx|            USA|    A|       A5|       Not Verified|                13000.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |397305d16894aaf85...|     Program Manager|         1|          RENT|      50000.0|           CA|          920xx|            USA|    E|       E5|           Verified|               100675.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |659176bbda64d233d...|Automation Specia...|         2|           OWN|     210000.0|           TX|          773xx|            USA|    A|       A5|    Source Verified|               512009.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |e386a896fde5d4650...|         coordinator|        10|      MORTGAGE|      90000.0|           TN|          372xx|            USA|    E|       E1|           Verified|                89518.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |77f808a6e53a679c7...|   Research directot|        10|          RENT|      86000.0|           LA|          705xx|            USA|    D|       D4|           Verified|               394584.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |923cc14545abb9e74...|       Administrator|        10|      MORTGAGE|     130000.0|           VA|          243xx|            USA|    C|       C3|    Source Verified|               294184.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |247ac2e64aacb8172...|      Budget Manager|         8|      MORTGAGE|      98000.0|           OH|          440xx|            USA|    F|       F4|           Verified|               617540.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |367de6ca2bf23e9ae...|Communications Ma...|         5|          RENT|      81000.0|           CA|          946xx|            USA|    A|       A4|       Not Verified|                40000.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |4abfc1fa646b5bfd7...|           physician|        10|      MORTGAGE|     250000.0|           WI|          544xx|            USA|    A|       A3|    Source Verified|               416395.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |e9916dd537667d30d...|      Police officer|         3|          RENT|     110000.0|           CA|          917xx|            USA|    C|       C4|       Not Verified|                69000.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |5064789e43a2e4677...|                Cook|         2|           OWN|      38000.0|           CA|          923xx|            USA|    C|       C3|    Source Verified|               104454.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |53884509c91f73fd7...|                null|         6|          RENT|      24000.0|           WA|          983xx|            USA|    A|       A1|       Not Verified|                36300.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |e6f5ab3d6fe1e7f21...|                r.n.|         7|           OWN|      69000.0|           OK|          748xx|            USA|    C|       C3|           Verified|               333048.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |b8a64093e9966a300...|           Principal|         1|          RENT|      75000.0|           CT|          067xx|            USA|    E|       E5|           Verified|               189733.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |a6228367f8cca2446...|   Senior Consultant|         3|          RENT|      87500.0|           CA|          946xx|            USA|    B|       B2|    Source Verified|                49173.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |f2c644fcd6f358f27...|             Manager|         1|      MORTGAGE|      80000.0|           MI|          494xx|            USA|    C|       C3|       Not Verified|                25900.0|      Individual|              null|                     null|2026-01-17 23:23:...|
# |68b6a7e5d432ff111...|                null|         6|      MORTGAGE|      30000.0|           SC|          294xx|            USA|    B|       B2|    Source Verified|                18514.0|       Joint App|           49908.0|          Source Verified|2026-01-17 23:23:...|
# +--------------------+--------------------+----------+--------------+-------------+-------------+---------------+---------------+-----+---------+-------------------+-----------------------+----------------+------------------+-------------------------+--------------------+
# only showing top 20 rows

# %%
customers_state_cleaned.select("address_state").distinct()
# Out:
# +-------------+
# |address_state|
# +-------------+
# |           SC|
# |           AZ|
# |           LA|
# |           MN|
# |           NJ|
# |           DC|
# |           OR|
# |           NA|
# |           VA|
# |         null|
# |           RI|
# |           KY|
# |           WY|
# |           NH|
# |           MI|
# |           NV|
# |           WI|
# |           ID|
# |           CA|
# |           CT|
# +-------------+
# only showing top 20 rows

# %% [markdown]
# ## Write the cleaned customers data to a cleaned folder in hdfs

# %%
customers_state_cleaned.write \
.format("parquet") \
.mode("overwrite") \
.option("path","/user/itv022692/lendingclubproject/cleaned/customers_parquet") \
.save()

# %%
customers_state_cleaned.write \
.format("csv") \
.mode("overwrite") \
.option("path","/user/itv022692/lendingclubproject/cleaned/customers_csv") \
.save()
